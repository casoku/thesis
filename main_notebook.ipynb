# %%
from IPython.display import display
import spot
from spot.jupyter import display_inline
spot.setup()

# %%
a = spot.translate('(a U b) & GFc & GFd', 'Buchi', 'state-based', 'complete'); a
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fcef01e1c00> >

# %%
# %run main_9_rooms.py
# Out:
# Creating state of HLM
# Done creating state of HLM
# Creating edges for HLM
# Done creating edges for HLM
# (0.83, 46.26, S13, S14, 0)
# (0.82, 39.41, S11, S14, 0)
# (0.56, 39.32, S11, S14, 0)
# E1, S1, S2, 1.00, 8.50
# E2, S2, S1, 0.90, 8.33
# E3, S1, S3, 0.99, 8.33
# E4, S3, S1, 0.90, 8.04
# E5, S3, S2, 0.97, 8.15
# E6, S2, S3, 0.96, 8.27
# E7, S2, S4, 0.96, 7.22
# E8, S2, S3, 0.94, 8.10
# E9, S2, S5, 0.79, 7.04
# E10, S5, S2, 0.85, 7.35
# E11, S4, S5, 0.96, 8.30
# E12, S5, S4, 0.96, 8.06
# E13, S5, S6, 0.91, 7.26
# E14, S6, S5, 0.94, 7.45
# E15, S3, S7, 0.96, 7.22
# E16, S7, S3, 0.96, 7.16
# E17, S3, S8, 0.87, 7.30
# E18, S8, S3, 0.93, 8.10
# E19, S8, S7, 0.99, 8.21
# E20, S7, S8, 0.98, 8.46
# E21, S7, S4, 0.98, 6.10
# E22, S4, S7, 0.98, 6.32
# E23, S7, S9, 0.91, 7.24
# E24, S9, S7, 0.94, 7.72
# E25, S7, S10, 0.96, 7.51
# E26, S10, S7, 0.83, 8.33
# E27, S10, S4, 0.96, 7.15
# E28, S4, S10, 1.00, 7.19
# E29, S10, S9, 0.98, 8.20
# E30, S9, S10, 0.96, 8.20
# E31, S7, S10, 0.95, 7.82
# E32, S10, S7, 0.90, 8.18
# E33, S10, S6, 0.99, 6.22
# E34, S6, S10, 0.94, 6.45
# E35, S10, S11, 0.98, 7.37
# E36, S11, S10, 0.92, 7.23
# E37, S6, S11, 0.89, 7.38
# E38, S11, S6, 0.90, 8.03
# E39, S8, S12, 0.98, 7.43
# E40, S12, S8, 0.96, 7.19
# E41, S12, S9, 0.96, 6.27
# E42, S9, S12, 0.90, 6.16
# E43, S12, S13, 0.93, 7.66
# E44, S13, S12, 0.90, 8.52
# E45, S13, S9, 0.94, 7.44
# E46, S9, S13, 0.93, 7.44
# E47, S13, S14, 0.88, 9.86
# E48, S14, S13, 0.93, 10.54
# E49, S13, S11, 0.95, 6.21
# E50, S11, S13, 1.00, 6.12
# E51, S11, S14, 0.87, 9.14
# E52, S14, S11, 0.89, 9.56
# (1.00, 0.00, None, S1, 0)
# (1.00, 8.50, S1, S2, 0)
# (0.99, 8.33, S1, S3, 0)
# (0.96, 15.72, S2, S4, 0)
# (0.92, 24.02, S4, S5, 0)
# (0.79, 15.54, S2, S5, 0)
# (0.95, 29.13, S10, S6, 0)
# (0.72, 22.80, S5, S6, 0)
# (0.95, 15.55, S3, S7, 0)
# (0.93, 24.01, S7, S8, 0)
# (0.86, 15.63, S3, S8, 0)
# (0.94, 31.11, S10, S9, 0)
# (0.86, 22.79, S7, S9, 0)
# (0.96, 22.91, S4, S10, 0)
# (0.94, 30.28, S10, S11, 0)
# (0.64, 30.18, S6, S11, 0)
# (0.91, 31.44, S8, S12, 0)
# (0.84, 23.06, S8, S12, 0)
# (0.94, 36.40, S11, S13, 0)
# (0.80, 30.23, S9, S13, 0)
# (0.83, 46.26, S13, S14, 0)
# (0.82, 39.41, S11, S14, 0)
# (0.56, 39.32, S11, S14, 0)
# ---------------------------------------------------
# (1.00, 0.00, None, S1, 0)
# (1.00, 8.50, S1, S2, 0)
# (0.99, 8.33, S1, S3, 0)
# (0.96, 15.72, S2, S4, 0)
# (0.92, 24.02, S4, S5, 0)
# (0.79, 15.54, S2, S5, 0)
# (0.95, 29.13, S10, S6, 0)
# (0.72, 22.80, S5, S6, 0)
# (0.95, 15.55, S3, S7, 0)
# (0.93, 24.01, S7, S8, 0)
# (0.86, 15.63, S3, S8, 0)
# (0.94, 31.11, S10, S9, 0)
# (0.86, 22.79, S7, S9, 0)
# (0.96, 22.91, S4, S10, 0)
# (0.94, 30.28, S10, S11, 0)
# (0.64, 30.18, S6, S11, 0)
# (0.91, 31.44, S8, S12, 0)
# (0.94, 36.40, S11, S13, 0)
# (0.80, 30.23, S9, S13, 0)
# (0.83, 46.26, S13, S14, 0)
# (0.82, 39.41, S11, S14, 0)
# ---------------------------------------------------
# ['S1', 'S2', 'S4', 'S10', 'S11', 'S13', 'S14']
# E1, S1, S2, 1.00, 8.50
# E7, S2, S4, 0.96, 7.22
# E28, S4, S10, 1.00, 7.19
# E35, S10, S11, 0.98, 7.37
# E50, S11, S13, 1.00, 6.12
# E47, S13, S14, 0.88, 9.86
# ['S1', 'S2', 'S4', 'S10', 'S6', 'S11', 'S13', 'S14']
# E1, S1, S2, 1.00, 8.50
# E7, S2, S4, 0.96, 7.22
# E28, S4, S10, 1.00, 7.19
# E33, S10, S6, 0.99, 6.22
# E37, S6, S11, 0.89, 7.38
# E50, S11, S13, 1.00, 6.12
# E47, S13, S14, 0.88, 9.86
# ['S1', 'S2', 'S4', 'S5', 'S6', 'S11', 'S13', 'S14']
# E1, S1, S2, 1.00, 8.50
# E7, S2, S4, 0.96, 7.22
# E11, S4, S5, 0.96, 8.30
# E13, S5, S6, 0.91, 7.26
# E37, S6, S11, 0.89, 7.38
# E50, S11, S13, 1.00, 6.12
# E47, S13, S14, 0.88, 9.86
# ['S1', 'S2', 'S5', 'S6', 'S11', 'S13', 'S14']
# E1, S1, S2, 1.00, 8.50
# E9, S2, S5, 0.79, 7.04
# E13, S5, S6, 0.91, 7.26
# E37, S6, S11, 0.89, 7.38
# E50, S11, S13, 1.00, 6.12
# E47, S13, S14, 0.88, 9.86
# ['S1', 'S2', 'S4', 'S10', 'S9', 'S13', 'S14']
# E1, S1, S2, 1.00, 8.50
# E7, S2, S4, 0.96, 7.22
# E28, S4, S10, 1.00, 7.19
# E29, S10, S9, 0.98, 8.20
# E46, S9, S13, 0.93, 7.44
# E47, S13, S14, 0.88, 9.86
# ['S1', 'S3', 'S7', 'S9', 'S13', 'S14']
# E3, S1, S3, 0.99, 8.33
# E15, S3, S7, 0.96, 7.22
# E23, S7, S9, 0.91, 7.24
# E46, S9, S13, 0.93, 7.44
# E47, S13, S14, 0.88, 9.86
# ['S1', 'S2', 'S4', 'S10', 'S11', 'S14']
# E1, S1, S2, 1.00, 8.50
# E7, S2, S4, 0.96, 7.22
# E28, S4, S10, 1.00, 7.19
# E35, S10, S11, 0.98, 7.37
# E51, S11, S14, 0.87, 9.14
# ['S1', 'S2', 'S4', 'S10', 'S6', 'S11', 'S14']
# E1, S1, S2, 1.00, 8.50
# E7, S2, S4, 0.96, 7.22
# E28, S4, S10, 1.00, 7.19
# E33, S10, S6, 0.99, 6.22
# E37, S6, S11, 0.89, 7.38
# E51, S11, S14, 0.87, 9.14
# ['S1', 'S2', 'S4', 'S5', 'S6', 'S11', 'S14']
# E1, S1, S2, 1.00, 8.50
# E7, S2, S4, 0.96, 7.22
# E11, S4, S5, 0.96, 8.30
# E13, S5, S6, 0.91, 7.26
# E37, S6, S11, 0.89, 7.38
# E51, S11, S14, 0.87, 9.14
# ['S1', 'S2', 'S5', 'S6', 'S11', 'S14']
# E1, S1, S2, 1.00, 8.50
# E9, S2, S5, 0.79, 7.04
# E13, S5, S6, 0.91, 7.26
# E37, S6, S11, 0.89, 7.38
# E51, S11, S14, 0.87, 9.14
# [{'edges': [<Util.Edge.Edge object at 0x7fce44800850>, <Util.Edge.Edge object at 0x7fce4196a0a0>, <Util.Edge.Edge object at 0x7fce4178eeb0>, <Util.Edge.Edge object at 0x7fce44a00af0>, <Util.Edge.Edge object at 0x7fce449decd0>, <Util.Edge.Edge object at 0x7fce41a12d30>], 'probability': 0.827904, 'cost': 46.259733302411874}, {'edges': [<Util.Edge.Edge object at 0x7fce44800850>, <Util.Edge.Edge object at 0x7fce41962100>, <Util.Edge.Edge object at 0x7fce44a5a340>, <Util.Edge.Edge object at 0x7fce419887f0>, <Util.Edge.Edge object at 0x7fce449decd0>, <Util.Edge.Edge object at 0x7fce41a12d30>], 'probability': 0.5630424800000001, 'cost': 46.16736978282704}, {'edges': [<Util.Edge.Edge object at 0x7fce449af5b0>, <Util.Edge.Edge object at 0x7fce44b760d0>, <Util.Edge.Edge object at 0x7fce41a06c40>, <Util.Edge.Edge object at 0x7fce44b24250>, <Util.Edge.Edge object at 0x7fce41a12d30>], 'probability': 0.7078046976, 'cost': 40.098338153781704}, {'edges': [<Util.Edge.Edge object at 0x7fce44800850>, <Util.Edge.Edge object at 0x7fce4196a0a0>, <Util.Edge.Edge object at 0x7fce4178eeb0>, <Util.Edge.Edge object at 0x7fce44a00af0>, <Util.Edge.Edge object at 0x7fce42becf10>], 'probability': 0.818496, 'cost': 39.41402797325827}, {'edges': [<Util.Edge.Edge object at 0x7fce44800850>, <Util.Edge.Edge object at 0x7fce41962100>, <Util.Edge.Edge object at 0x7fce44a5a340>, <Util.Edge.Edge object at 0x7fce419887f0>, <Util.Edge.Edge object at 0x7fce42becf10>], 'probability': 0.55664427, 'cost': 39.321664453673435}]
# 5
# Demonstrating capabilities
# new controller = E1
# new controller start: name: S1, low_level: [1, 1], goal: name: S2, low_level: [7, 3]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S2, low_level: [7, 3]
# [20, 20]
# new controller = E7
# new controller start: name: S2, low_level: [7, 3], goal: name: S4, low_level: [10, 7]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S4, low_level: [10, 7]
# [20, 20]
# new controller = E28
# new controller start: name: S4, low_level: [10, 7], goal: name: S10, low_level: [14, 10]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S10, low_level: [14, 10]
# [20, 20]
# new controller = E35
# new controller start: name: S10, low_level: [14, 10], goal: name: S11, low_level: [17, 14]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S11, low_level: [17, 14]
# [20, 20]
# new controller = E50
# new controller start: name: S11, low_level: [17, 14], goal: name: S13, low_level: [14, 17]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S13, low_level: [14, 17]
# [20, 20]
# new controller = E47
# new controller start: name: S13, low_level: [14, 17], goal: name: S14, low_level: [20, 20]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S14, low_level: [20, 20]
# [20, 20]
# goal reached! :)
# Demonstrating capabilities
# new controller = E1
# new controller start: name: S1, low_level: [1, 1], goal: name: S2, low_level: [7, 3]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S2, low_level: [7, 3]
# [20, 20]
# new controller = E7
# new controller start: name: S2, low_level: [7, 3], goal: name: S4, low_level: [10, 7]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S4, low_level: [10, 7]
# [20, 20]
# new controller = E28
# new controller start: name: S4, low_level: [10, 7], goal: name: S10, low_level: [14, 10]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S10, low_level: [14, 10]
# [20, 20]
# new controller = E35
# new controller start: name: S10, low_level: [14, 10], goal: name: S11, low_level: [17, 14]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S11, low_level: [17, 14]
# [20, 20]
# new controller = E50
# new controller start: name: S11, low_level: [17, 14], goal: name: S13, low_level: [14, 17]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S13, low_level: [14, 17]
# [20, 20]
# new controller = E47
# new controller start: name: S13, low_level: [14, 17], goal: name: S14, low_level: [20, 20]
# {'task_complete': True, 'ball': False, 'lava': False}
# name: S14, low_level: [20, 20]
# [20, 20]
# goal reached! :)
# calculated pareto cost: 46.259733302411874
# average cost: 45.5
# calculated pareto probability: 0.827904
# success rate: 1.0
